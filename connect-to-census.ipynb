# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# ## 👉 download your data
#
# You can write code here to download your dataset. Or if you already have it, just leave the URL in the comments and just load it into a pandas or R (or both) dataframe.

# %%
import pandas as pd
df=pd.read_csv('privateschools.csv')
df
# Out:
#                 X          Y  OBJECTID      PPIN  \
# 0      -86.541877  32.472090         1      2722
# 1      -86.458475  32.469350         2  A0100060
# 2      -86.472061  32.460800         3  A0900032
# 3      -86.466175  32.455425         4  A1592005
# 4      -86.470441  32.461710         5  K9300030
# ...           ...        ...       ...       ...
# 22340 -110.810241  43.491060     22341  A0303404
# 22341 -110.799526  43.458650     22342  A0903887
# 22342 -110.844286  43.367002     22343  A1102418
# 22343 -110.810901  43.441910     22344  A2000010
# 22344 -110.812671  43.459650     22345  A9301070
#
#                                             NAME                       STREET  \
# 0                                AUTAUGA ACADEMY                497 GOLSON RD
# 1                           CAMELLIA BAPTIST WEM              201 WOODVALE RD
# 2                FIRST PRESBYTERIAN KINDERGARTEN            211 S CHESTNUT ST
# 3                               NEW HOPE ACADEMY                 301 WATER ST
# 4       FIRST BAPTIST PRESCHOOL AND KINDERGARTEN          138 S WASHINGTON ST
# ...                                          ...                          ...
# 22340  MOUNTAIN ACADEMY OF TETON SCIENCE SCHOOLS         700 COYOTE CANYON RD
# 22341              JACKSON HOLE COMMUNITY SCHOOL  1715 HIGH SCHOOL ROAD, #240
# 22342                            RED TOP MEADOWS           7905 FALL CREEK RD
# 22343             JACKSON HOLE CLASSICAL ACADEMY          2500 S PARK LOOP RD
# 22344             JACKSON HOLE CHRISTIAN ACADEMY          1450 S PARK LOOP RD
#
#              CITY STATE    ZIP  STFIP  ...          NMCBSA CBSATYPE  CSA  \
# 0      PRATTVILLE    AL  36067      1  ...  Montgomery, AL        1  388
# 1      PRATTVILLE    AL  36067      1  ...  Montgomery, AL        1  388
# 2      PRATTVILLE    AL  36067      1  ...  Montgomery, AL        1  388
# 3      PRATTVILLE    AL  36067      1  ...  Montgomery, AL        1  388
# 4      PRATTVILLE    AL  36067      1  ...  Montgomery, AL        1  388
# ...           ...   ...    ...    ...  ...             ...      ...  ...
# 22340     JACKSON    WY  83001     56  ...  Jackson, WY-ID        2    N
# 22341     JACKSON    WY  83001     56  ...  Jackson, WY-ID        2    N
# 22342      WILSON    WY  83014     56  ...  Jackson, WY-ID        2    N
# 22343     JACKSON    WY  83001     56  ...  Jackson, WY-ID        2    N
# 22344     JACKSON    WY  83001     56  ...  Jackson, WY-ID        2    N
#
#                                      NMCSA  NECTA NMNECTA    CD   SLDL   SLDU  \
# 0      Montgomery-Selma-Alexander City, AL      N       N   102   1069   1030
# 1      Montgomery-Selma-Alexander City, AL      N       N   102   1088   1030
# 2      Montgomery-Selma-Alexander City, AL      N       N   102   1088   1030
# 3      Montgomery-Selma-Alexander City, AL      N       N   102   1088   1030
# 4      Montgomery-Selma-Alexander City, AL      N       N   102   1088   1030
# ...                                    ...    ...     ...   ...    ...    ...
# 22340                                    N      N       N  5600  56023  56017
# 22341                                    N      N       N  5600  56016  56017
# 22342                                    N      N       N  5600  56022  56016
# 22343                                    N      N       N  5600  56023  56017
# 22344                                    N      N       N  5600  56016  56017
#
#       SCHOOLYEAR
# 0      2021-2022
# 1      2021-2022
# 2      2021-2022
# 3      2021-2022
# 4      2021-2022
# ...          ...
# 22340  2021-2022
# 22341  2021-2022
# 22342  2021-2022
# 22343  2021-2022
# 22344  2021-2022
#
# [22345 rows x 26 columns]

# %% [markdown]
# ## 👉 convert addresses --> lat/long
#
# See the [census-examples](https://github.com/data4news/census-examples) repository for examples. If you need help, try asking in the class slack channel. Chances are someone in the class is struggling with the same problem as you are so we might as well all learn together in the same slack channel!

# %%
#My dataset has lat and long data.

# %% [markdown]
# ## 👉 convert lat/long to census geography codes
#
# (like 'GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK', etc...)
#
# Same note as above, see [census-examples](https://github.com/data4news/census-examples) repository for examples or ask in the class slack channel if stuck.

# %%
# !pip install requests-cache
# Out:
# Collecting requests-cache
#   Using cached requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: attrs>=21.2 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests-cache) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests-cache) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests-cache) (4.3.6)
# Requirement already satisfied: requests>=2.22 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests-cache) (2.32.3)
# Requirement already satisfied: url-normalize>=1.4 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests-cache) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests>=2.22->requests-cache) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests>=2.22->requests-cache) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests>=2.22->requests-cache) (2024.8.30)
# Requirement already satisfied: six in /Users/ananya/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from url-normalize>=1.4->requests-cache) (1.16.0)
# Using cached requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Installing collected packages: requests-cache
# Successfully installed requests-cache-1.2.1
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import censusgeocode as cg
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm
import requests_cache
import csv  
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

df = pd.read_csv('privateschools.csv')

def geocode(lat, lng):
    try:
        url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
        params = {
            "x": lng,
            "y": lat,
            "benchmark": "Public_AR_Census2020",
            "vintage": "Census2020_Census2020",
            "format": "json"
        }
        response = cache.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        
        # Check if the required key exists before accessing it
        if 'result' in data and 'geographies' in data['result'] and 'Census Blocks' in data['result']['geographies']:
            return data['result']['geographies']['Census Blocks'][0]
        else:
            print(f"Warning: No census data found for ({lat}, {lng})")
            return None
    except Exception as e:
        print(f"Error geocoding ({lat}, {lng}): {e}")
        return None

with open('censusgeos.csv', 'w', newline='') as f:
    header = ['SUFFIX', 'POP100', 'GEOID', 'CENTLAT', 'BLOCK', 'AREAWATER', 'STATE', 'BASENAME', 'OID', 'LSADC', 'INTPTLAT', 'FUNCSTAT', 'NAME', 'OBJECTID', 'TRACT', 'CENTLON', 'BLKGRP', 'AREALAND', 'HU100', 'INTPTLON', 'MTFCC', 'LWBLKTYP', 'UR', 'COUNTY']
    writer = csv.DictWriter(f, fieldnames=header)
    
    writer.writeheader()
    
    for _, row in tqdm(df.iterrows(), total=len(df)):
        json_data = geocode(row['LAT'], row['LON'])
        if json_data:  # Check if geocode() returned a valid dictionary
            writer.writerow(json_data)
        else:
            print(f"Skipping row with coordinates ({row['LAT']}, {row['LON']}) due to missing data.")
# Out:
#   0%|          | 0/22345 [00:00<?, ?it/s]
# Error geocoding (37.56244, -122.380821): Expecting value: line 1 column 1 (char 0)
# Skipping row with coordinates (37.56244, -122.380821) due to missing data.
# Error geocoding (39.29272, -80.346121): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Skipping row with coordinates (39.29272, -80.346121) due to missing data.

# %% [markdown]
# ## 👉 Output Data
#
# Output your dataframe containing your data and the Census connector codes (like tract, block, etc...).

# %%
import pandas as pd
df=pd.read_csv("privateschools_with_geocodes.csv")
df
# Out:
#                 X          Y  OBJECTID      PPIN  \
# 0      -86.541877  32.472090         1      2722
# 1      -86.458475  32.469350         2  A0100060
# 2      -86.472061  32.460800         3  A0900032
# 3      -86.466175  32.455425         4  A1592005
# 4      -86.470441  32.461710         5  K9300030
# ...           ...        ...       ...       ...
# 22340 -110.810241  43.491060     22341  A0303404
# 22341 -110.799526  43.458650     22342  A0903887
# 22342 -110.844286  43.367002     22343  A1102418
# 22343 -110.810901  43.441910     22344  A2000010
# 22344 -110.812671  43.459650     22345  A9301070
#
#                                             NAME                       STREET  \
# 0                                AUTAUGA ACADEMY                497 GOLSON RD
# 1                           CAMELLIA BAPTIST WEM              201 WOODVALE RD
# 2                FIRST PRESBYTERIAN KINDERGARTEN            211 S CHESTNUT ST
# 3                               NEW HOPE ACADEMY                 301 WATER ST
# 4       FIRST BAPTIST PRESCHOOL AND KINDERGARTEN          138 S WASHINGTON ST
# ...                                          ...                          ...
# 22340  MOUNTAIN ACADEMY OF TETON SCIENCE SCHOOLS         700 COYOTE CANYON RD
# 22341              JACKSON HOLE COMMUNITY SCHOOL  1715 HIGH SCHOOL ROAD, #240
# 22342                            RED TOP MEADOWS           7905 FALL CREEK RD
# 22343             JACKSON HOLE CLASSICAL ACADEMY          2500 S PARK LOOP RD
# 22344             JACKSON HOLE CHRISTIAN ACADEMY          1450 S PARK LOOP RD
#
#              CITY STATE    ZIP  STFIP  ...  CSA  \
# 0      PRATTVILLE    AL  36067      1  ...  388
# 1      PRATTVILLE    AL  36067      1  ...  388
# 2      PRATTVILLE    AL  36067      1  ...  388
# 3      PRATTVILLE    AL  36067      1  ...  388
# 4      PRATTVILLE    AL  36067      1  ...  388
# ...           ...   ...    ...    ...  ...  ...
# 22340     JACKSON    WY  83001     56  ...    N
# 22341     JACKSON    WY  83001     56  ...    N
# 22342      WILSON    WY  83014     56  ...    N
# 22343     JACKSON    WY  83001     56  ...    N
# 22344     JACKSON    WY  83001     56  ...    N
#
#                                      NMCSA  NECTA  NMNECTA    CD   SLDL  \
# 0      Montgomery-Selma-Alexander City, AL      N        N   102   1069
# 1      Montgomery-Selma-Alexander City, AL      N        N   102   1088
# 2      Montgomery-Selma-Alexander City, AL      N        N   102   1088
# 3      Montgomery-Selma-Alexander City, AL      N        N   102   1088
# 4      Montgomery-Selma-Alexander City, AL      N        N   102   1088
# ...                                    ...    ...      ...   ...    ...
# 22340                                    N      N        N  5600  56023
# 22341                                    N      N        N  5600  56016
# 22342                                    N      N        N  5600  56022
# 22343                                    N      N        N  5600  56023
# 22344                                    N      N        N  5600  56016
#
#         SLDU SCHOOLYEAR  Census_Tract          County
# 0       1030  2021-2022  1.001020e+09  Autauga County
# 1       1030  2021-2022  1.001021e+09  Autauga County
# 2       1030  2021-2022  1.003011e+09  Baldwin County
# 3       1030  2021-2022  1.001020e+09  Autauga County
# 4       1030  2021-2022  1.003011e+09  Baldwin County
# ...      ...        ...           ...             ...
# 22340  56017  2021-2022  5.603997e+10    Teton County
# 22341  56017  2021-2022  5.603997e+10    Teton County
# 22342  56016  2021-2022  5.603997e+10    Teton County
# 22343  56017  2021-2022  5.603997e+10    Teton County
# 22344  56017  2021-2022  5.603997e+10    Teton County
#
# [22345 rows x 28 columns]
